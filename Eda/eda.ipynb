# %% [markdown]
# # EDA

# %% [markdown]
# ![Screenshot 2024-06-12 120904.png](<attachment:Screenshot 2024-06-12 120904.png>)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ## Step 1:- Read Dataframe

# %%
import pandas as pd
df=pd.read_csv('iris.csv')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Step 2:- check basic information about dataframe

# %%
df.shape
# Out:
# (150, 5)

# %%
df.count()
# Out:
# sepal_length    150
# sepal_width     150
# petal_length    150
# petal_width     150
# species         150
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# ## Step 3:- Descrptive statistics

# %%
cat=list(df.columns[df.dtypes=='object'])
cat
# Out:
# ['species']

# %%
con=list(df.columns[df.dtypes!='object'])
con
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
df[con].describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df[cat].describe().T
# Out:
#         count unique     top freq
# species   150      3  setosa   50

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# ## Step 4:- visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df['species'].value_counts().plot(kind='bar',title='count plot for species')
# Out:
# <Axes: title={'center': 'count plot for species'}, xlabel='species'>

# %%
for i in con:
    sns.histplot(data=df, x=i, kde=True)
    plt.title(f'histrogram for {i}')
    plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1.sctterplot

# %% [markdown]
# its use for con Vs con

# %%
plt.figure(figsize=(16,8))
plt.scatter(df['sepal_length'],df['sepal_width'])
plt.xlabel('sepal_length')
plt.ylabel('sepal_width')
plt.title('Sepal Length vs Sepal Width')
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.scatter(df['petal_length'],df['petal_width'])
plt.xlabel('petal_length')
plt.ylabel('petal_width')
plt.title('petal Length vs prtal Width')
plt.show()

# %%
import numpy as np

# %% [markdown]
# ### correlation

# %%
corr = df.select_dtypes(include=[np.number]).corr()

# %%
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(df.select_dtypes(include=[np.number]).corr(), annot=True, fmt='.3f')
# Out:
# <Axes: >

# %% [markdown]
# ## Sctterplot

# %%
plt.scatter(df['petal_length'],df['sepal_length'])

# %% [markdown]
# ## cat vs con

# %%
sns.boxplot(data=df,x='species',y='sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
for i in con:
    sns.boxplot(data=df, x='species',y=i)
    plt.show()

# %%
sns.pairplot(data=df)

# %%
sns.pairplot(data=df,hue='species')
